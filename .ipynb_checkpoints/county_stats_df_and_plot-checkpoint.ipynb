# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
county_stats_1_file = "raw data/2019_county_stats_1.csv"
stats_1_df = pd.read_csv(county_stats_1_file, encoding="latin")

# %%
stats_1_df
# Out:
#     FIPS          State         County  % Fair/Poor Health  \
# 0   6075     California  San Francisco                  12
# 1   6081     California      San Mateo                  12
# 2  36061       New York       New York                  15
# 3   8097       Colorado         Pitkin                  10
# 4  25019  Massachusetts      Nantucket                  12
#
#    Physically Unhealthy Days  Mentally Unhealthy Days  % Smokers  % Obese  \
# 0                        3.0                      3.2         10       19
# 1                        2.7                      2.9          9       21
# 2                        3.4                      3.6         13       16
# 3                        3.0                      3.1         13       15
# 4                        3.3                      3.9         15       23
#
#    % Physically Inactive  % Excessive Drinking            ...              \
# 0                     15                    24            ...
# 1                     15                    17            ...
# 2                     18                    27            ...
# 3                     11                    23            ...
# 4                     17                    23            ...
#
#    80th Percentile Income  20th Percentile Income  Income Ratio  \
# 0                  206392                   28893           7.1
# 1                  212707                   43754           4.9
# 2                  200587                   21926           9.1
# 3                  147111                   35664           4.1
# 4                  159746                   42769           3.7
#
#    # Single-Parent Households  # Households  % Single-Parent Households  \
# 0                       28925        114867                          25
# 1                       34347        160691                          21
# 2                       94490        237190                          40
# 3                         852          2852                          30
# 4                         727          2212                          33
#
#    Annual Average Violent Crimes  Violent Crime Rate Average Daily PM2.5  \
# 0                           6546                 760                 9.8
# 1                           1598                 209                 9.2
# 2                           9634                 586                10.8
# 3                             11                  62                 4.0
# 4                             17                 158                 6.0
#
#    % Severe Housing Problems
# 0                         26
# 1                         24
# 2                         25
# 3                         19
# 4                         22
#
# [5 rows x 44 columns]
